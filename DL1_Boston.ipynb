# %%
import pandas as pd
from sklearn import preprocessing

# Load the Boston Housing dataset from a local CSV file
file_path = "C://Users//jaikrishna//OneDrive//Desktop//LP5//LP5//bh.csv"
df = pd.read_csv(file_path)

# Separate features (X) and target variable (y)
X = df.drop("MEDV", axis=1)  # Adjust target_column_name with the actual name of your target variable
y = df["MEDV"]  # Same adjustment here

# Preprocess the data if needed (scaling, normalization, etc.)
scaler = preprocessing.StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split the data into training and testing sets
from sklearn.model_selection import train_test_split
train_x, test_x, train_y, test_y = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
df
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio       b  lstat  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
print("train shape: ",train_x.shape)
print("test shape: ",test_x.shape)
print("actual train output:",train_y.shape)
print("actual test output:",test_y.shape)
# Out:
# train shape:  (404, 13)
# test shape:  (102, 13)
# actual train output: (404,)
# actual test output: (102,)

# %%
#normalization for preprocessing
train_x=preprocessing.normalize(train_x)
test_x=preprocessing.normalize(test_x)

# %%
# from tensorflow.python import metrics
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
def HousePricePredictionModel():  
	model=Sequential()
	model.add(Dense(128,activation='relu',input_shape=(train_x[0].shape)))
	model.add(Dense(64,activation='relu'))
	model.add(Dense(32,activation='relu'))
	model.add(Dense(1))
	model.compile(optimizer='adam',loss='mse',metrics=['mae'])
	return model

# %%
import numpy as np
k=4
num_val_samples=len(train_x)
num_epochs=10
all_scores=[]

# %%
model= HousePricePredictionModel()
history=model.fit(x=train_x,y=train_y,epochs=num_epochs,batch_size=1,verbose=1,validation_data=(test_x,test_y))
# Out:
# C:\Users\jaikrishna\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\core\dense.py:86: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/10
# 404/404 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 306.0244 - mae: 13.5649 - val_loss: 28.3040 - val_mae: 3.3671
# Epoch 2/10
# 404/404 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 23.1503 - mae: 3.5663 - val_loss: 23.2289 - val_mae: 3.0796
# Epoch 3/10
# 404/404 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 22.9622 - mae: 3.1863 - val_loss: 22.2858 - val_mae: 2.8847
# Epoch 4/10
# 404/404 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 22.6418 - mae: 3.1410 - val_loss: 18.0472 - val_mae: 2.6617
# Epoch 5/10
# 404/404 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 16.4901 - mae: 2.8415 - val_loss: 15.9672 - val_mae: 2.5961
# Epoch 6/10
# ...

# %%
mse, mae = model.evaluate(test_x, test_y)
print('Mean squared error on test data: ', mse)
print('Mean absolute error on test data: ', mae)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 10.6784 - mae: 2.3049
# Mean squared error on test data:  13.37863826751709
# Mean absolute error on test data:  2.4512274265289307
